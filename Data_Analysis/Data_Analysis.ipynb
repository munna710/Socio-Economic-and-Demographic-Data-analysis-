# %%
# %pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Read the dataset
df = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\census_income_data2.csv")

# %%
df.head()
# Out:
#    Age                     Worker_Class  Industry_Code  Occupation_Code  \
# 0   73                  Not in universe              0                0
# 1   58   Self-employed-not incorporated              4               34
# 2   18                  Not in universe              0                0
# 3    9                  Not in universe              0                0
# 4   10                  Not in universe              0                0
#
#                Education_Level         Schooling  Marital_Status  \
# 0         High school graduate   Not in universe         Widowed
# 1   Some college but no degree   Not in universe        Divorced
# 2                   10th grade       High school   Never married
# 3                     Children   Not in universe   Never married
# 4                     Children   Not in universe   Never married
#
#                        Industry                            Occupation  \
# ...

# %%
# Replace missing values in Mother_Nativity and Father_Nativity columns based on Citizenship column
mask = df['Citizenship'] == 'Native- Born in the United States'
df.loc[mask, 'Mother_Nativity'] = 'United-States'
df.loc[mask, 'Father_Nativity'] = 'United-States'

# %%
df.head()
# Out:
#    Age                     Worker_Class  Industry_Code  Occupation_Code  \
# 0   73                  Not in universe              0                0
# 1   58   Self-employed-not incorporated              4               34
# 2   18                  Not in universe              0                0
# 3    9                  Not in universe              0                0
# 4   10                  Not in universe              0                0
#
#                Education_Level         Schooling  Marital_Status  \
# 0         High school graduate   Not in universe         Widowed
# 1   Some college but no degree   Not in universe        Divorced
# 2                   10th grade       High school   Never married
# 3                     Children   Not in universe   Never married
# 4                     Children   Not in universe   Never married
#
#                        Industry                            Occupation  \
# ...

# %%
# Standardize the format in the Income_Bracket column
df['Income_Bracket'] = df['Income_Bracket'].replace({'50000+.': '>50000', '-50000': '<=50000'})

# %%
# Convert Survey_Year to four-digit year format
df['Survey_Year'] = df['Survey_Year'].apply(lambda x: 1900 + int(x))

# %%
df.head()
# Out:
#    Age                     Worker_Class  Industry_Code  Occupation_Code  \
# 0   73                  Not in universe              0                0
# 1   58   Self-employed-not incorporated              4               34
# 2   18                  Not in universe              0                0
# 3    9                  Not in universe              0                0
# 4   10                  Not in universe              0                0
#
#                Education_Level         Schooling  Marital_Status  \
# 0         High school graduate   Not in universe         Widowed
# 1   Some college but no degree   Not in universe        Divorced
# 2                   10th grade       High school   Never married
# 3                     Children   Not in universe   Never married
# 4                     Children   Not in universe   Never married
#
#                        Industry                            Occupation  \
# ...

# %%
# Define the condition
condition = (df['Personal_Nativity'].isnull()) & (df['Mother_Nativity'].isnull()) & (df['Father_Nativity'].isnull()) & (df['Citizenship'] == 'Foreign born- Not a citizen of U S')

# Update the values
# If Personal_Nativity, Mother_Nativity, and Father_Nativity are null
# and Citizenship is 'Foreign born- Not a citizen of U S', then change the values to 'Foreign'
df.loc[condition, ['Personal_Nativity', 'Mother_Nativity', 'Father_Nativity']] = 'Foreign'

# %%
print(df.dtypes)
# Out:
# Age                            int64
# Worker_Class                  object
# Industry_Code                  int64
# Occupation_Code                int64
# Education_Level               object
# Schooling                     object
# Marital_Status                object
# Industry                      object
# Occupation                    object
# Race                          object
# Ancestry                      object
# Gender                        object
# Union_Member                  object
# Unemployment_Reason           object
# Employment_Status             object
# Capital_Gains                  int64
# Capital_Losses                 int64
# Dividends                      int64
# Tax_Filing_Status             object
# Previous_Residence_Reason     object
# Previous_State                object
# Household_Stats               object
# Household_Summary             object
# Marital_Support              float64
# MSA_Change                    object
# ...

# %%
df.head(10)
# Out:
#    Age                     Worker_Class  Industry_Code  Occupation_Code  \
# 0   73                  Not in universe              0                0
# 1   58   Self-employed-not incorporated              4               34
# 2   18                  Not in universe              0                0
# 3    9                  Not in universe              0                0
# 4   10                  Not in universe              0                0
# 5   48                          Private             40               10
# 6   42                          Private             34                3
# 7   28                          Private              4               40
# 8   47                 Local government             43               26
# 9   34                          Private              4               37
#
#                Education_Level         Schooling  \
# 0         High school graduate   Not in universe
# 1   Some college but no degree   Not in universe
# ...

# %%
# Calculate summary statistics
summary_stats = df[['Dividends', 'Capital_Gains', 'Capital_Losses']].describe()
print(summary_stats)

# Plot histograms
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['Dividends'], kde=True)
plt.title('Dividends Distribution')

plt.subplot(1, 3, 2)
sns.histplot(df['Capital_Gains'], kde=True)
plt.title('Capital Gains Distribution')

plt.subplot(1, 3, 3)
sns.histplot(df['Capital_Losses'], kde=True)
plt.title('Capital Losses Distribution')

plt.tight_layout()
plt.show()

# Plot box plots
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.boxplot(y=df['Dividends'])
plt.title('Dividends Box Plot')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['Capital_Gains'])
plt.title('Capital Gains Box Plot')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['Capital_Losses'])
plt.title('Capital Losses Box Plot')

plt.tight_layout()
plt.show()
# Out:
#            Dividends  Capital_Gains  Capital_Losses
# count  199523.000000   199523.00000   199523.000000
# mean      197.529533      434.71899       37.313788
# std      1984.163658     4697.53128      271.896428
# min         0.000000        0.00000        0.000000
# 25%         0.000000        0.00000        0.000000
# 50%         0.000000        0.00000        0.000000
# 75%         0.000000        0.00000        0.000000
# max     99999.000000    99999.00000     4608.000000

# %%
# Handling Outliers
# Trim extreme values (e.g., top 1% and bottom 1%)
trim_low = df[['Dividends', 'Capital_Gains', 'Capital_Losses']].quantile(0.01)
trim_high = df[['Dividends', 'Capital_Gains', 'Capital_Losses']].quantile(0.99)
df_trimmed = df[(df[['Dividends', 'Capital_Gains', 'Capital_Losses']] >= trim_low) & (df[['Dividends', 'Capital_Gains', 'Capital_Losses']] <= trim_high)]

# Summary Statistics
summary_stats = df_trimmed[['Dividends', 'Capital_Gains', 'Capital_Losses']].describe()
print(summary_stats)

# Visualization
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df_trimmed['Dividends'], kde=True)
plt.title('Dividends Distribution')

plt.subplot(1, 3, 2)
sns.histplot(df_trimmed['Capital_Gains'], kde=True)
plt.title('Capital Gains Distribution')

plt.subplot(1, 3, 3)
sns.histplot(df_trimmed['Capital_Losses'], kde=True)
plt.title('Capital Losses Distribution')

plt.tight_layout()
plt.show()

# Box plots
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.boxplot(y=df_trimmed['Dividends'])
plt.title('Dividends Box Plot')

plt.subplot(1, 3, 2)
sns.boxplot(y=df_trimmed['Capital_Gains'])
plt.title('Capital Gains Box Plot')

plt.subplot(1, 3, 3)
sns.boxplot(y=df_trimmed['Capital_Losses'])
plt.title('Capital Losses Box Plot')

plt.tight_layout()
plt.show()
# Out:
#            Dividends  Capital_Gains  Capital_Losses
# count  197529.000000  197596.000000   197583.000000
# mean       65.484258     120.228066       16.154173
# std       355.087310     810.825549      164.029248
# min         0.000000       0.000000        0.000000
# 25%         0.000000       0.000000        0.000000
# 50%         0.000000       0.000000        0.000000
# 75%         0.000000       0.000000        0.000000
# max      4550.000000    8614.000000     1887.000000

# %%
# Check for missing values and replace them with appropriate values
df.fillna(0, inplace=True)  # Replace NaN with 0

# Calculate Hourly_Pay only for rows where Hourly_Pay is currently zero
condition = (df['Hourly_Pay'] == 0)

# Check for division by zero in Weeks_Worked
zero_weeks_worked = (df['Weeks_Worked'] == 0)

# Calculate Hourly_Pay only for rows where Hourly_Pay is currently zero and Weeks_Worked is not zero
hourly_pay_calculation = (df['Dividends'] - (df['Capital_Gains'] + df['Capital_Losses'])) / df['Weeks_Worked']
default_hourly_pay = 10  # Set a default value for Hourly_Pay when numerator is zero
df.loc[condition & ~zero_weeks_worked, 'Hourly_Pay'] = hourly_pay_calculation
df.loc[condition & (hourly_pay_calculation == 0), 'Hourly_Pay'] = default_hourly_pay

# Handle cases where Weeks_Worked is zero (avoid division by zero)
df.loc[zero_weeks_worked, 'Hourly_Pay'] = 0

# Calculate average hourly pay for positive values
average_hourly_pay = df[df['Hourly_Pay'] > 0]['Hourly_Pay'].mean()

# Replace negative hourly pay values with average hourly pay for positive values
df.loc[df['Hourly_Pay'] < 0, 'Hourly_Pay'] = average_hourly_pay
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24236\3598697726.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[   0.          -99.57692308    0.         ... -123.25          3.01923077
#     0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[condition & ~zero_weeks_worked, 'Hourly_Pay'] = hourly_pay_calculation

# %%
df.head(10)
# Out:
#    Age                     Worker_Class  Industry_Code  Occupation_Code  \
# 0   73                  Not in universe              0                0
# 1   58   Self-employed-not incorporated              4               34
# 2   18                  Not in universe              0                0
# 3    9                  Not in universe              0                0
# 4   10                  Not in universe              0                0
# 5   48                          Private             40               10
# 6   42                          Private             34                3
# 7   28                          Private              4               40
# 8   47                 Local government             43               26
# 9   34                          Private              4               37
#
#                Education_Level         Schooling  \
# 0         High school graduate   Not in universe
# 1   Some college but no degree   Not in universe
# ...

# %%
print(df[['Dividends', 'Capital_Gains', 'Capital_Losses']])
# Out:
#         Dividends  Capital_Gains  Capital_Losses
# 0               0              0               0
# 1               0              0               0
# 2               0              0               0
# 3               0              0               0
# 4               0              0               0
# ...           ...            ...             ...
# 199518          0              0               0
# 199519          9           6418               0
# 199520        157              0               0
# 199521          0              0               0
# 199522          0              0               0
#
# [199523 rows x 3 columns]

# %%
# Replace null values in 'Sunbelt_Migration' with "Not in universe"
df['Sunbelt_Migration'].fillna('Not in universe', inplace=True)

# %%
# Check for null values in any column
null_columns = df.columns[df.isnull().any()]

# Print the columns with null values, if any
if null_columns.empty:
    print("No null values found in any column.")
else:
    print("Null values found in the following columns:")
    print(null_columns)
# Out:
# No null values found in any column.

# %%
# Exploratory Data Analysis (EDA)
# Analyzing the distribution of 'Age' using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], bins=30, kde=True, color='blue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualizing the distribution of 'Income_Bracket' using a count plot
plt.figure(figsize=(8, 6))
sns.countplot(x='Income_Bracket', data=df, palette='viridis')
plt.title('Distribution of Income Bracket')
plt.xlabel('Income Bracket')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24236\284810299.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Income_Bracket', data=df, palette='viridis')

# %%
# Exploring the relationship between 'Education_Level' and 'Income_Bracket'
plt.figure(figsize=(10, 8))
sns.boxplot(x='Education_Level', y='Income_Bracket', data=df, palette='pastel')
plt.title('Income Bracket by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24236\882487725.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Education_Level', y='Income_Bracket', data=df, palette='pastel')

# %%
# Calculating descriptive statistics for numeric columns
print(df.describe())
# Out:
#                  Age  Industry_Code  Occupation_Code  Capital_Gains  \
# count  199523.000000  199523.000000    199523.000000   199523.00000
# mean       34.494199      15.352320        11.306556      434.71899
# std        22.310895      18.067129        14.454204     4697.53128
# min         0.000000       0.000000         0.000000        0.00000
# 25%        15.000000       0.000000         0.000000        0.00000
# 50%        33.000000       0.000000         0.000000        0.00000
# 75%        50.000000      33.000000        26.000000        0.00000
# max        90.000000      51.000000        46.000000    99999.00000
#
#        Capital_Losses      Dividends  Marital_Support  Employers_Count  \
# count   199523.000000  199523.000000    199523.000000    199523.000000
# mean        37.313788     197.529533      1740.380269         1.956180
# std        271.896428    1984.163658       993.768156         2.365126
# ...

# %%
#Calculating value counts for categorical columns
print(df['Race'].value_counts())
# Out:
# Race
#  White                          167365
#  Black                           20415
#  Asian or Pacific Islander        5835
#  Other                            3657
#  Amer Indian Aleut or Eskimo      2251
# Name: count, dtype: int64

# %%
# Correlation heatmap for numeric columns
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Correlation heatmap for numeric columns
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Get value counts for 'Race' column
race_counts = df['Race'].value_counts()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(race_counts, labels=race_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Races')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Demographic Influences on Income (Age, Gender, Race, etc.)
plt.figure(figsize=(10, 6))
sns.boxplot(x='Income_Bracket', y='Age', data=df)
plt.title('Income Distribution by Age')
plt.xlabel('Income Bracket')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Income_Bracket', hue='Gender', data=df)
plt.title('Income Distribution by Gender')
plt.xlabel('Income Bracket')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Income_Bracket', hue='Race', data=df)
plt.title('Income Distribution by Race')
plt.xlabel('Income Bracket')
plt.ylabel('Count')
plt.legend(title='Race')
plt.show()

# %%
# Socioeconomic Factors (Education, Employment Type) and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education_Level', y='Income_Bracket', data=df)
plt.title('Income Distribution by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the average income for each combination of employment status and income bracket
average_income = df.groupby(['Employment_Status', 'Income_Bracket']).agg({'Income_Bracket': 'count'}).unstack()

# Plotting
plt.figure(figsize=(12, 8))

# Bar plot for average income by employment status and income bracket
average_income.plot(kind='bar', stacked=True)

# Add title and labels
plt.title('Average Income by Employment Status and Income Bracket')
plt.xlabel('Employment Status')
plt.ylabel('Number of Individuals')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.legend(['<= 50000', '> 50000'], title='Income Bracket')
plt.tight_layout()
plt.show()

# %%
# Family and Household Dynamics Correlated with Income Levels
plt.figure(figsize=(10, 6))
sns.boxplot(x='Marital_Status', y='Income_Bracket', data=df)
plt.title('Income Distribution by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Set up the figure and axes
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 12))

# Family and Household Dynamics Correlated with Income Levels
sns.barplot(ax=axes[0], x='Marital_Status', y='Income_Bracket', data=df, ci=None)
axes[0].set_title('Average Income by Marital Status')
axes[0].set_xlabel('Marital Status')
axes[0].set_ylabel('Average Income')
axes[0].tick_params(axis='x', rotation=45)

# Geographic and Migration Insights
sns.barplot(ax=axes[1], x='Region_Change', y='Income_Bracket', data=df, ci=None)
axes[1].set_title('Average Income by Region Change')
axes[1].set_xlabel('Region Change')
axes[1].set_ylabel('Average Income')
axes[1].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24236\1680024917.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(ax=axes[0], x='Marital_Status', y='Income_Bracket', data=df, ci=None)
# C:\Users\user\AppData\Local\Temp\ipykernel_24236\1680024917.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(ax=axes[1], x='Region_Change', y='Income_Bracket', data=df, ci=None)

# %%
# Economic Factors (Investment Income, Losses) and Income
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Capital_Gains', y='Capital_Losses', hue='Income_Bracket', data=df)
plt.title('Income Distribution by Capital Gains and Losses')
plt.xlabel('Capital Gains')
plt.ylabel('Capital Losses')
plt.legend(title='Income Bracket')
plt.show()

# %%
# Work Status and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Income_Bracket', y='Weeks_Worked', hue='Employment_Status', data=df)
plt.title('Income Distribution by Employment Status and Weeks Worked')
plt.xlabel('Income Bracket')
plt.ylabel('Weeks Worked')
plt.legend(title='Employment Status')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar plot for Employment Status and Income
plt.figure(figsize=(10, 6))
sns.countplot(x='Employment_Status', hue='Income_Bracket', data=df)
plt.title('Income Distribution by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.legend(title='Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Pie chart for Tax Filing Status
plt.figure(figsize=(8, 8))
df['Tax_Filing_Status'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Tax Filing Status')
plt.ylabel('')
plt.show()

# %%
# Grouped bar chart for Marital Support and Income
plt.figure(figsize=(10, 6))
sns.barplot(x='Income_Bracket', y='Marital_Support', data=df)
plt.title('Average Marital Support by Income Bracket')
plt.xlabel('Income Bracket')
plt.ylabel('Average Marital Support')
plt.xticks(rotation=45)
plt.show()

# %%
# Convert Survey_Year column to string type
df['Survey_Year'] = df['Survey_Year'].astype(str)

# Extract integer part of Survey_Year values
df['Survey_Year'] = df['Survey_Year'].apply(lambda x: int(x.split('.')[0]))

# %%
df.head()
# Out:
#    Age                     Worker_Class  Industry_Code  Occupation_Code  \
# 0   73                  Not in universe              0                0
# 1   58   Self-employed-not incorporated              4               34
# 2   18                  Not in universe              0                0
# 3    9                  Not in universe              0                0
# 4   10                  Not in universe              0                0
#
#                Education_Level         Schooling  Marital_Status  \
# 0         High school graduate   Not in universe         Widowed
# 1   Some college but no degree   Not in universe        Divorced
# 2                   10th grade       High school   Never married
# 3                     Children   Not in universe   Never married
# 4                     Children   Not in universe   Never married
#
#                        Industry                            Occupation  \
# ...

# %%
# Education and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education_Level', y='Weeks_Worked', hue='Income_Bracket', data=df)
plt.title('Income Distribution by Education Level and Weeks Worked')
plt.xlabel('Education Level')
plt.ylabel('Weeks Worked')
plt.legend(title='Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Occupation and Income
plt.figure(figsize=(12, 8))
sns.barplot(x='Income_Bracket', y='Occupation', data=df)
plt.title('Average Occupation by Income Bracket')
plt.xlabel('Income Bracket')
plt.ylabel('Occupation')
plt.xticks(rotation=45)
plt.show()

# %%
# Geographic Location and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region_Change', y='Income_Bracket', data=df)
plt.title('Income Distribution by Region Change')
plt.xlabel('Region Change')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Employer Count and Income
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Employers_Count', y='Income_Bracket', data=df)
plt.title('Income Distribution by Number of Employers')
plt.xlabel('Number of Employers')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Dependents and Income
plt.figure(figsize=(10, 6))
sns.countplot(x='Dependents', hue='Income_Bracket', data=df)
plt.title('Income Distribution by Dependents')
plt.xlabel('Dependents')
plt.ylabel('Count')
plt.legend(title='Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Business Ownership and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Business_Ownership', y='Income_Bracket', data=df)
plt.title('Income Distribution by Business Ownership')
plt.xlabel('Business Ownership')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Veteran Benefits and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Veteran_Benefits', y='Income_Bracket', data=df)
plt.title('Income Distribution by Veteran Benefits')
plt.xlabel('Veteran Benefits')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Household Dynamics and Income
plt.figure(figsize=(10, 6))
sns.boxplot(x='Household_Stats', y='Income_Bracket', data=df)
plt.title('Income Distribution by Household Size')
plt.xlabel('Household Size')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Work Experience and Income
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Weeks_Worked', y='Income_Bracket', data=df)
plt.title('Income Distribution by Weeks Worked')
plt.xlabel('Weeks Worked')
plt.ylabel('Income Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
# Generate a boxplot for 'Hourly_Pay' by 'Education_Level'
plt.figure(figsize=(10, 6))
df.boxplot(column='Hourly_Pay', by='Education_Level')
plt.title('Hourly Pay by Education Level')
plt.suptitle('')
plt.xlabel('Education Level')
plt.ylabel('Hourly Pay')
plt.xticks(rotation=45)
plt.show()

# %%
veteran_benefits_pay = df.groupby('Veteran_Benefits')['Hourly_Pay'].mean()

# Plotting the results
veteran_benefits_pay.plot(kind='bar')
plt.title('Average Hourly Pay by Veteran Benefits')
plt.xlabel('Veteran Benefits')
plt.ylabel('Average Hourly Pay')
plt.show()

# %%
# Demographic Profiles
def plot_demographics(df):
    demographic_cols = ['Age', 'Race', 'Gender', 'Ancestry']
    for col in demographic_cols:
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.show()

# Employment Patterns
def plot_employment_patterns(df):
    employment_cols = ['Worker_Class', 'Industry', 'Occupation']
    for col in employment_cols:
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.show()

# Educational Attainment
def plot_education_attainment(df):
    df.groupby('Education_Level')['Income_Bracket'].value_counts().unstack().plot(kind='bar', stacked=True)
    plt.title('Income Bracket by Education Level')
    plt.xlabel('Education Level')
    plt.ylabel('Count')
    plt.show()

# Income Analysis
def income_analysis(df):
    df['Net_Capital'] = df['Capital_Gains'] - df['Capital_Losses']
    df.groupby('Income_Bracket')[['Net_Capital', 'Dividends']].mean().plot(kind='bar')
    plt.title('Average Capital Gains, Losses, and Dividends by Income Bracket')
    plt.xlabel('Income Bracket')
    plt.ylabel('Average Amount')
    plt.show()
    

# Work-Life Balance
def work_life_balance(df):
    df.plot(kind='scatter', x='Weeks_Worked', y='Hourly_Pay')
    plt.title('Correlation between Weeks Worked and Hourly Pay')
    plt.xlabel('Weeks Worked')
    plt.ylabel('Hourly Pay')
    plt.show()

# Migration Patterns
def migration_patterns(df):
    migration_cols = ['MSA_Change', 'Region_Change', 'Within_Region_Move', 'Sunbelt_Migration']
    for col in migration_cols:
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.show()

# Family Dynamics
def family_dynamics(df):
    df.groupby('Marital_Status')['Dependents'].value_counts().unstack().plot(kind='bar', stacked=True)
    plt.title('Dependents by Marital Status')
    plt.xlabel('Marital Status')
    plt.ylabel('Count')
    plt.show()

# Economic Impact
def economic_impact(df):
    df.groupby('Business_Ownership')['Employers_Count'].mean().plot(kind='bar')
    plt.title('Average Number of Employers by Business Ownership')
    plt.xlabel('Business Ownership')
    plt.ylabel('Average Number of Employers')
    plt.show()

# Veteran Affairs
def veteran_affairs(df):
    df.groupby('Veteran_Benefits')['Hourly_Pay'].mean().plot(kind='bar')
    plt.title('Average Hourly Pay by Veteran Benefits')
    plt.xlabel('Veteran Benefits')
    plt.ylabel('Average Hourly Pay')
    plt.show()

# Run all analysis functions
plot_demographics(df)
plot_employment_patterns(df)
plot_education_attainment(df)
income_analysis(df)
work_life_balance(df)
migration_patterns(df)
family_dynamics(df)
economic_impact(df)
veteran_affairs(df)

# %%
# Clean 'Worker_Class' column
df['Worker_Class'] = df['Worker_Class'].replace({'Not in universe': 'Not Applicable'})

# %%
# Export cleaned data
df.to_csv('cleaned_dataset.csv', index=False)
